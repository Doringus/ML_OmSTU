# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# Загрузим датасет

# %%
diabetes_data = pd.read_csv("../data/diabetes/diabetes.csv", index_col = 0)

# %% [markdown]
# Посмотрим на распределение больных в датасете

# %%
sns.countplot(diabetes_data['Class'], data = diabetes_data)

# %% [markdown]
# Видно, что в выборке число больных больше, чем число здоровых

# %% [markdown]
# Посмотрим распределение по полу

# %%
sns.countplot(diabetes_data['Gender'], data = diabetes_data, hue = diabetes_data['Class'])

# %% [markdown]
# Количество здоровых мужчин в выборке значительно больше чем количество женщин

# %% [markdown]
# Рассмотрим как различные симптомы могут показывать наличие диабета

# %%
sns.countplot(diabetes_data['Polyuria'], data = diabetes_data, hue = diabetes_data['Class'])

# %%
sns.countplot(diabetes_data['Polydipsia'], data = diabetes_data, hue = diabetes_data['Class'])

# %% [markdown]
# Этот признак отчетливо показывает, что полидипсия показатель наличия диабета.

# %%
sns.countplot(diabetes_data['Sudden_Weight_Loss'], data = diabetes_data, hue = diabetes_data['Class'])

# %%
sns.countplot(diabetes_data['Weakness'], data = diabetes_data, hue = diabetes_data['Class'])

# %%
sns.countplot(diabetes_data['Polyphagia'], data = diabetes_data, hue = diabetes_data['Class'])

# %%
sns.countplot(diabetes_data['Genital_thrush'], data = diabetes_data, hue = diabetes_data['Class'])

# %% [markdown]
# Данный признак не является показательным

# %%
sns.countplot(diabetes_data['Visual_Blurring'], data = diabetes_data, hue = diabetes_data['Class'])

# %%
sns.countplot(diabetes_data['Itching'], data = diabetes_data, hue = diabetes_data['Class'])

# %%
sns.countplot(diabetes_data['Irritability'], data = diabetes_data, hue = diabetes_data['Class'])

# %%
sns.countplot(diabetes_data['Delayed_Healing'], data = diabetes_data, hue = diabetes_data['Class'])

# %%
sns.countplot(diabetes_data['Partial_Paresis'], data = diabetes_data, hue = diabetes_data['Class'])

# %%
sns.countplot(diabetes_data['Muscle_Stiffness'], data = diabetes_data, hue = diabetes_data['Class'])

# %%
sns.countplot(diabetes_data['Alopecia'], data = diabetes_data, hue = diabetes_data['Class'])

# %%
sns.countplot(diabetes_data['Obesity'], data = diabetes_data, hue = diabetes_data['Class'])

# %% [markdown]
# Ожирение также не является показательным признаком

# %% [markdown]
# Загрузим обработанные данные, чтобы построить heatmap

# %%
diabetes_data = pd.read_csv("../data/diabetes/diabetes_preprocessed.csv", index_col = 0)

# %%
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(diabetes_data.corr(), annot=True, linewidths=.5, ax=ax)

# %% [markdown]
# Как и на предыдущих графиках видна зависимость между наличием ожирения и полиурией и полидипсией
